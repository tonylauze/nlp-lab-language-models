# %% [markdown]
# # NLP Lab : Modèles de langue
#
# Dans ce tp, nous allons constuire les briques principales du modèle GPT2 et entrainer un petit modèle sur des poèmes de Victor Hugo.
#
# Les questions sont posées dans ce notebook, puis pour executer l'entrainement, il faudra modifier le ficher `gpt_single_head.py` aussi disponible dans le reposository git.
#
#
# ## Données
#
# Les données d'entrainement sont un recueil de poèmes de Victor Hugo issu du site [gutenberg.org](https://www.gutenberg.org/). Elles sont disponibles dans le répertoire `data`.
#
# Afin de réduire la complexité du modèle, nous allons modéliser le texte au niveau caractère. Les modèles de language modélisent généralement des séquences de sous-mots en utilisant des [tokenizers](https://huggingface.co/docs/transformers/tokenizer_summary) (BPE, SentencePiece, WordPiece)
#
# Questions :
# >* En utilisant [collections.Counter](https://docs.python.org/3/library/collections.html#collections.Counter), afficher le nombre de caractères différents dans le texte et la fréquence de chaque caractère.

# %%
import collections

with open('data/hugo_contemplations.txt', 'r', encoding='utf-8') as f:
    text = f.read()

print(f'Number of characters in the file: {len(text)}')
##  YOUR CODE HERE

# Créer un compteur de caractères
counter = collections.Counter(text)

# Extraire les caractères uniques
chars = list(counter.keys())

###

print (f'Number of character in counter: {sum(counter.values())}')
print (f'{len(chars)} different characters')
print (counter)
# Out:
# Number of characters in the file: 285222
# Number of character in counter: 285222
# 101 different characters
# Counter({' ': 49127, 'e': 30253, 's': 17987, 'u': 14254, 'r': 14223, 't': 14071, 'a': 14048, 'n': 13725, 'i': 12828, 'o': 12653, 'l': 11638, '\n': 8102, 'm': 6495, 'd': 6375, ',': 6077, 'c': 5074, 'p': 4206, "'": 3820, 'v': 3492, 'é': 2943, 'b': 2783, 'f': 2772, 'h': 2221, 'q': 1956, 'g': 1790, '.': 1420, 'x': 1154, 'L': 1147, '!': 1121, 'E': 1074, ';': 1043, '-': 1020, 'j': 890, 'D': 764, 'è': 725, 'à': 706, 'y': 660, 'I': 627, 'ê': 605, 'C': 593, 'S': 545, 'A': 530, 'Q': 503, 'z': 482, 'J': 471, 'O': 450, 'T': 441, 'P': 435, '?': 388, 'V': 383, 'â': 381, 'N': 362, 'M': 344, 'ù': 298, ':': 294, 'R': 240, 'î': 214, 'U': 208, 'ô': 159, 'X': 150, '1': 146, 'H': 116, 'F': 114, '5': 111, '8': 93, 'B': 78, '«': 74, 'É': 70, '»': 69, 'G': 67, '4': 64, 'û': 62, '3': 47, 'ç': 34, 'À': 33, 'ë': 32, 'ï': 31, '2': 30, '·': 26, 'Ê': 24, '6': 23, '7': 23, 'Ô': 19, '9': 19, 'È': 11, 'k': 10, '0': 10, '_': 8, 'Z': 7, 'Æ': 4, '[': 4, ']': 4, 'w': 3, 'K': 3, 'Y': 3, 'Ë': 2, '(': 2, ')': 2, 'Â': 2, 'Î': 1, 'W': 1})

# %% [markdown]
# ### Encodage / décodage
# Afin de transformer le texte en vecteur pour le réseau de neurones, il faut encoder chaque caractère avec un entier. Les fonctions suivantes opérent l'encodage et le décodage des caractères :

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: transform a string into a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: transform a list of integers into a string


# test that your encoder/decoder is coherent
testString = "\nDemain, dès l'aube"
print(encode (testString))
assert decode(encode (testString)) ==  testString
# Out:
# [3, 19, 35, 34, 52, 29, 30, 42, 14, 37, 33, 43, 14, 53, 20, 52, 32, 55, 35]

# %% [markdown]
# ### Découpage Train/Validation
#
# L'objectif étant de prédire des poèmes, il ne faut pas mélanger les lignes aléatoirement. Il faut garder l'ordre des lignes dans le texte et uniquement prendre les premiers 90% pour entrainer et les 10% restants pour contrôler l'apprentissage.
#
# Questions :
# > * Découper en `train_data` (90%) et `val_data` (10%) en utilisant du slicing sur data.

# %%
import torch
# Train and validation splits
data = torch.tensor(encode(text), dtype=torch.long)
print(data[:100])
## YOUR CODE HERE
# first 90% will be train, rest val
train_size = int(len(data) * 0.9)
train_data = data[:train_size]
val_data = data[train_size:]
###
# Out:
# tensor([ 0,  1,  2,  3,  4,  5,  6,  7,  1,  8,  9,  0, 10,  7, 11,  5,  6,  2,
#          3,  3,  9, 10, 12,  3,  3, 13, 11,  4,  7,  5, 12, 14, 15, 16, 17,  5,
#          3,  3,  3, 11, 11,  3,  3, 10, 16, 18,  5, 16, 12, 19, 20, 15, 16, 11,
#         21, 22, 22, 23, 24, 25, 26, 22, 23, 24, 27, 28,  3,  3,  4, 29, 30, 31,
#         32, 29, 33, 34, 35, 14, 36, 37, 29, 38, 29, 39, 30,  3,  3,  3,  4,  5,
#          0,  0,  1,  4,  7, 11,  5,  6, 14, 15])

# %% [markdown]
# ### Contexte
#
# Le modèle de langue possède comme paramètre la taille maximale du contexte à considérer pour faire la prédiction du prochain caractère. Ce contexte est appelé `block_size`. Les données d'apprentissage sont donc des séquences de caractères consécutifs, issues de l'ensemble d'entraînenement tirées aléatoirement et de longueur `block_size`.
#
# Si le caractère de début de la séquence est `i`, la séquence de contexte est donc :
# ``` x = data[i:i+block_size]```
# et la valeur à prédire à chaque position dans le contexte est le caractère suivant :
# ```y = [data[i+1:i+block_size+1]```.

# %%
block_size = 8

i  = torch.randint(len(data) - block_size, (1,))
print (i)
x = train_data[i:i+block_size]
y = train_data[i+1:i+1+block_size]

for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print (f'context is >{decode(context.tolist())}< target is >{decode([target.tolist()])}<')
# Out:
# tensor([6302])
# context is >-< target is >v<
# context is >-v< target is >o<
# context is >-vo< target is >u<
# context is >-vou< target is >s<
# context is >-vous< target is > <
# context is >-vous < target is >é<
# context is >-vous é< target is >p<
# context is >-vous ép< target is >r<

# %% [markdown]
# ### Définition des batchs
#
# Les batchs d'entrainement sont constitués de plusieurs séquences de caractères tirées aléatoirement dans `train_data`. Pour choisir aléatoirement une séquence à mettre dans le batch, il faut tirer aléatoirement un point de départ dans `train_data` et extraire les `block_size` caractères suivants. Lors du tirage du point de départ, faire attention à laisser suffisamment de caractères après le point de départ pour avoir une séquence de `block_size` caractères.
#
# Questions :
# > * Créer les batchs `x` en tirant `batch_size` séquences de longeur `block_size` à  partir d'un point `i` tiré aléatoirement. Empiler les exemples avec `torch.stack`.
# > * Créer les batchs `y` en ajoutant le caractère suivant la séquence `x`. Empiler les exemples avec `torch.stack`.

# %%
batch_size = 4
torch.manual_seed(2023)
# data loading
def get_batch(split):
    data = train_data if split == 'train' else val_data
    x_list, y_list = [], []

    for _ in range(batch_size):
        start_idx = torch.randint(0, len(data) - block_size - 1, (1,)).item()
        x_seq = data[start_idx : start_idx + block_size]
        y_seq = data[start_idx + 1 : start_idx + block_size + 1]
        x_list.append(x_seq)
        y_list.append(y_seq)

    x = torch.stack(x_list)
    y = torch.stack(y_list)

    x, y = x.to(device), y.to(device)
    return x, y

# %% [markdown]
# ### Premier modèle : un bigramme
#
# Le premier modèle que nous allons implémenter est un modèle bigramme. Il prédit le caractère suivant uniquement en fonction du caractère courant. Il est possible de stocker ce modèle dans une simple matrice : pour chaque caractère (en ligne), on stocke la distribution de probabilités sur l'ensemble des caractères suivants (en colonne). On peut donc le stocker dans une simple couche [`Embedding`](https://pytorch.org/docs/stable/generated/torch.nn.Embedding.html).
#
# Questions :
# > * Dans le constructeur, définir une couche Embedding de taille `vocab_size` par `vocab_size`.
# > * Dans forward, appliquer la couche d'embedding au batch de idx (`x`).
# > * Dans forward, définir la loss comme la `cross_entropy` entre la prédiction et target (`y`).

# %%
import torch.nn as nn

# use a gpu if we have one
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self, vocab_size):
        super().__init__()
        # On utilise une couche Embedding pour stocker les probabilités de chaque token donné un token précédent
        self.embedding = nn.Embedding(vocab_size, vocab_size)

    def forward(self, idx, targets=None):
        # idx est un tenseur (Batch, Time) d'entiers
        logits = self.embedding(idx)  # (B, T, C) où C = vocab_size
        
        if targets is None:
            loss = None
        else:
            # Si targets est fourni, on calcule la perte
            B, T, C = logits.shape
            logits_flat = logits.view(B * T, C)  # Aplatir les logits pour les utiliser avec CrossEntropyLoss
            targets_flat = targets.view(B * T)  # Aplatir les targets pour CrossEntropyLoss
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits_flat, targets_flat)
        
        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx est un tenseur (B, T) d'indices dans le contexte actuel
        for _ in range(max_new_tokens):
            # Obtenir les prédictions
            logits, _ = self(idx)  # On ne se soucie pas de la loss pendant la génération
            logits = logits[:, -1, :]  # Ne garder que le dernier pas de temps, forme (B, C)
            probs = nn.functional.softmax(logits, dim=-1)  # Calculer la distribution de probabilité (B, C)
            
            # Correction ici : torch.multinomial attend une distribution de probabilité 2D (B, C)
            idx_next = torch.multinomial(probs, num_samples=1)  # Échantillonner parmi les probabilités (B, 1)

            # Ajouter le token généré à la séquence, forme (B, T+1)
            idx = torch.cat((idx, idx_next), dim=1)

        return idx
        
# Exemple d'initialisation du modèle
model = BigramLanguageModel(vocab_size=100)
m = model.to(device)

# %% [markdown]
# #### Modèle avant entraînement
# Le modèle n'a pas encore été entrainé, il est juste initialisé, mais on peut calculer la loss sur un batch aléatoire. Les poids étant initialisés avec une distribution normale N(0,1) sur chaque dimension, la loss attendue après l'initialisation devrait être proche de `-ln(1/vocab_size)` (l'entropie est maximale).

# %%
import math
vocab_size=100
xb, yb = get_batch('train')
logits, loss = m(xb, yb)
print (logits.shape)
print (f'loss attendue {-math.log(1.0/vocab_size)}')
print (f'loss calculée {loss}')
# Out:
# torch.Size([4, 8, 100])
# loss attendue 4.605170185988091
# loss calculée 5.2857184410095215

# %% [markdown]
# Pour utiliser le modèle en prédiction, il faut lui fournir un premier caractère pour amorcer la séquence : c'est le prompt. Dans notre cas, on peut initialiser la génération avec le caractère de retour à la ligne pour débuter une nouvelle phrase.
#
# Questions :
# > * Créer un prompt avec un tenseur de taille (1,1) contenant l'entier correspondant au caractère `\n`.
# > * Générer une séquence de caractères de taille 100 à partir de ce prompt avec les fonctions `m.generate` et `decode`.
# > * Comment est la phrase générée ?

# %%
# Récupérer l'indice du caractère '\n' directement depuis stoi
newline_idx = stoi['\n']

# Créer un tenseur de départ avec cet indice
start_token = torch.tensor([[newline_idx]], dtype=torch.long).to(device)

# Générer une séquence de 100 caractères
generated = m.generate(start_token, max_new_tokens=100)

# Décoder la séquence générée
generated_text = decode(generated[0].tolist())
print(generated_text)
# Out:
# ÂÆuËHM4:»jf-ÂOï?égè7Î;ÉèÂzÈYHz,C,MâBëwD)BoaÈG«'IÂCôHQu?8ûGÂrF]qBÊy5rû4ÊMa_a'vtj)dCé5ù6dtjwi5BWÂQkEbX

# %% [markdown]
# ### Entrainement
#
# Pour l'entrainement, nous utilisons un optimiseur [AdamW](https://pytorch.org/docs/stable/generated/torch.optim.AdamW.html) avec un learning rate de 1e-3. Une itération d'apprentissage consiste en
# - générer un batch
# - appliquer le réseau de neurones (forward) et calculer la loss (`model(xb, yb)`)
# - calculer le gradient (après avoir remis à zero le gradient cumulé) (`loss.backward()`)
# - mettre à jour les paramètres (`optimizer.step()`).

# %%
max_iters = 100
batch_size = 4
eval_interval = 10
learning_rate = 1e-3
eval_iters = 20
vocab_size = len(chars)

@torch.no_grad() # no gradient is computed here
def estimate_loss():
    """ Estimate the loss on eval_iters batch of train and val sets."""
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# re-create the model
model = BigramLanguageModel(vocab_size)
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = m(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 5.0743, val loss 5.2927
# step 10: train loss 5.1615, val loss 5.2968
# step 20: train loss 5.1046, val loss 5.3513
# step 30: train loss 5.1406, val loss 5.1887
# step 40: train loss 5.1470, val loss 5.1801
# step 50: train loss 5.0837, val loss 5.3022
# step 60: train loss 5.1129, val loss 5.2333
# step 70: train loss 5.0725, val loss 5.1986
# step 80: train loss 4.9924, val loss 5.2555
# step 90: train loss 5.1279, val loss 5.1964

# %% [markdown]
# Une fois le réseau entrainé pendant 100 itérations, on peut générer une séquence de caractères.
#
# Questions :
# > * Quel est l'effet de l'entraînement ?
# > * Augmenter le nombre d'itérations à 1000 puis à 10,000, noter la loss obtenue et la phrase générée. Qu'observez-vous ?

# %%
idx = torch.ones((1,1), dtype=torch.long)*3
print (decode(m.generate(idx, max_new_tokens=100)[0].tolist()))
# Out:
# ZÂ8,.0g!]kéc6(qrç·cëBÔvE!Â«JzGéévïÆë,f1gJW]Êr[D8li7è[2;LèÂnÈ2O?l«VÈ9gô7[6ANt!Y êwÎOq]2m-ô3ÀAR?mèlX(T

# %%
# générer du texte après les 100 premières itérations
idx = torch.ones((1,1), dtype=torch.long).to(device) * 3
generated_text_100 = decode(m.generate(idx, max_new_tokens=100)[0].tolist())
print("texte généré après 100 itérations:")
print(generated_text_100)

# continuer l'entraînement jusqu'à 1000 itérations
for iter in range(100, 1000):
   if iter % 100 == 0:
       losses = estimate_loss()
       print(f"étape {iter}: loss train {losses['train']:.4f}, loss val {losses['val']:.4f}")
   
   xb, yb = get_batch('train')
   logits, loss = m(xb, yb)
   optimizer.zero_grad(set_to_none=True)
   loss.backward()
   optimizer.step()

# générer du texte après 1000 itérations
generated_text_1000 = decode(m.generate(idx, max_new_tokens=100)[0].tolist())
print("\ntexte généré après 1000 itérations:")
print(generated_text_1000)

# continuer l'entraînement jusqu'à 10000 itérations
for iter in range(1000, 10000):
   if iter % 100 == 0:
       losses = estimate_loss()
       print(f"étape {iter}: loss train {losses['train']:.4f}, loss val {losses['val']:.4f}")
   
   xb, yb = get_batch('train')
   logits, loss = m(xb, yb)
   optimizer.zero_grad(set_to_none=True)
   loss.backward()
   optimizer.step()

# générer du texte après 10000 itérations
generated_text_10000 = decode(m.generate(idx, max_new_tokens=100)[0].tolist())
print("\ntexte généré après 10000 itérations:")
print(generated_text_10000)
# Out:
# Le caractère correspondant à l'indice 3 est: '
# '
# Texte généré après 100 itérations:
#
# î(àc0êlfU5izM3RW;,!ÈX?ûâ]'48xI-'É7, bg·nU3Zé.7[iÊh'qKe4Nzçq?Q1beFgÈYKS4pmÔkçUîPCù[CGgb
# xtjDX'VcpxkyH
# step 100: train loss 5.0351, val loss 5.2501
# step 110: train loss 5.0941, val loss 5.4020
# step 120: train loss 5.1066, val loss 5.2219
# step 130: train loss 5.1412, val loss 5.1863
# step 140: train loss 5.0418, val loss 5.2422
# step 150: train loss 5.0141, val loss 5.1230
# step 160: train loss 4.9864, val loss 5.1803
# step 170: train loss 4.9963, val loss 5.1212
# step 180: train loss 5.0436, val loss 5.1877
# step 190: train loss 4.9488, val loss 5.1122
# step 200: train loss 5.0038, val loss 5.1775
# step 210: train loss 4.9662, val loss 5.1605
# step 220: train loss 5.0337, val loss 5.3573
# step 230: train loss 5.0488, val loss 5.2079
# step 240: train loss 5.0868, val loss 5.0620
# step 250: train loss 5.0292, val loss 5.1717
# step 260: train loss 4.9614, val loss 5.1593
# step 270: train loss 4.9173, val loss 5.0649
# step 280: train loss 4.9561, val loss 5.1621
# step 290: train loss 4.8927, val loss 5.0677
# step 300: train loss 4.9856, val loss 5.1255
# step 310: train loss 4.8739, val loss 5.1115
# step 320: train loss 4.8520, val loss 5.0928
# step 330: train loss 4.8896, val loss 5.0733
# step 340: train loss 4.8885, val loss 5.0169
# step 350: train loss 4.8612, val loss 5.0413
# step 360: train loss 4.8619, val loss 5.0017
# step 370: train loss 4.9064, val loss 4.9548
# step 380: train loss 4.8996, val loss 5.1283
# step 390: train loss 4.8601, val loss 5.0425
# step 400: train loss 4.8698, val loss 4.8599
# step 410: train loss 4.7983, val loss 5.1811
# step 420: train loss 4.8460, val loss 4.9187
# step 430: train loss 4.7532, val loss 5.0732
# step 440: train loss 4.7257, val loss 5.0249
# step 450: train loss 4.6920, val loss 4.8954
# step 460: train loss 4.8471, val loss 5.0029
# step 470: train loss 4.8535, val loss 4.8854
# step 480: train loss 4.7257, val loss 4.8860
# step 490: train loss 4.6925, val loss 4.8549
# step 500: train loss 4.7732, val loss 4.9120
# step 510: train loss 4.7196, val loss 4.9657
# step 520: train loss 4.6977, val loss 4.9256
# step 530: train loss 4.7891, val loss 4.9838
# step 540: train loss 4.7302, val loss 4.8591
# step 550: train loss 4.6893, val loss 4.9289
# step 560: train loss 4.7525, val loss 4.9684
# step 570: train loss 4.6940, val loss 4.7631
# step 580: train loss 4.6621, val loss 4.8522
# step 590: train loss 4.7180, val loss 4.8577
# step 600: train loss 4.6860, val loss 4.8820
# step 610: train loss 4.7452, val loss 4.9172
# step 620: train loss 4.6644, val loss 4.7893
# step 630: train loss 4.6419, val loss 4.8248
# step 640: train loss 4.6646, val loss 4.7900
# step 650: train loss 4.5801, val loss 4.6986
# step 660: train loss 4.5441, val loss 4.7267
# step 670: train loss 4.5505, val loss 4.7994
# step 680: train loss 4.6422, val loss 4.7069
# step 690: train loss 4.6738, val loss 4.8959
# step 700: train loss 4.5619, val loss 4.7191
# step 710: train loss 4.6033, val loss 4.8104
# step 720: train loss 4.5539, val loss 4.7500
# step 730: train loss 4.5780, val loss 4.7929
# step 740: train loss 4.6747, val loss 4.7886
# step 750: train loss 4.5299, val loss 4.8503
# step 760: train loss 4.6131, val loss 4.8561
# step 770: train loss 4.5695, val loss 4.8116
# step 780: train loss 4.5053, val loss 4.7091
# step 790: train loss 4.5145, val loss 4.7414
# step 800: train loss 4.4666, val loss 4.7880
# step 810: train loss 4.5129, val loss 4.6860
# step 820: train loss 4.5191, val loss 4.7295
# step 830: train loss 4.4943, val loss 4.7898
# step 840: train loss 4.5881, val loss 4.5960
# step 850: train loss 4.4361, val loss 4.6731
# step 860: train loss 4.4661, val loss 4.6694
# step 870: train loss 4.4252, val loss 4.6273
# step 880: train loss 4.5107, val loss 4.6903
# step 890: train loss 4.4342, val loss 4.7185
# step 900: train loss 4.4266, val loss 4.8128
# step 910: train loss 4.3869, val loss 4.5435
# step 920: train loss 4.4473, val loss 4.6456
# step 930: train loss 4.3875, val loss 4.8275
# step 940: train loss 4.4609, val loss 4.7101
# step 950: train loss 4.4372, val loss 4.6018
# step 960: train loss 4.3219, val loss 4.7330
# step 970: train loss 4.4207, val loss 4.6420
# step 980: train loss 4.3297, val loss 4.6496
# step 990: train loss 4.4082, val loss 4.5969
#
# Texte généré après 1000 itérations:
#
# [u(p5D)ndï8ë5lWbU5ylô7tcauç6ÉB2;â'xÀL[ï8)LBG)Qn]oC29SgKg9tdP6·h;·Âp»4ÂX5i»t(qYôEpèÎ 9siU
# Fh6âéu(Ëk0:
# step 1000: train loss 4.4469, val loss 4.5322
# step 1010: train loss 4.4313, val loss 4.5255
# step 1020: train loss 4.3496, val loss 4.5184
# step 1030: train loss 4.3798, val loss 4.5792
# step 1040: train loss 4.3482, val loss 4.4860
# step 1050: train loss 4.5009, val loss 4.5276
# step 1060: train loss 4.3386, val loss 4.5287
# step 1070: train loss 4.3770, val loss 4.5169
# step 1080: train loss 4.3623, val loss 4.5181
# step 1090: train loss 4.3737, val loss 4.4728
# step 1100: train loss 4.3794, val loss 4.5792
# step 1110: train loss 4.3476, val loss 4.4093
# step 1120: train loss 4.2961, val loss 4.5360
# step 1130: train loss 4.2801, val loss 4.4730
# step 1140: train loss 4.2576, val loss 4.6208
# step 1150: train loss 4.2018, val loss 4.4925
# step 1160: train loss 4.3002, val loss 4.4839
# step 1170: train loss 4.3054, val loss 4.4948
# step 1180: train loss 4.3283, val loss 4.4626
# step 1190: train loss 4.3096, val loss 4.3735
# step 1200: train loss 4.2782, val loss 4.4732
# step 1210: train loss 4.2134, val loss 4.3624
# step 1220: train loss 4.3224, val loss 4.4298
# step 1230: train loss 4.1948, val loss 4.4262
# step 1240: train loss 4.2797, val loss 4.4297
# step 1250: train loss 4.2749, val loss 4.3601
# step 1260: train loss 4.1890, val loss 4.3919
# step 1270: train loss 4.3092, val loss 4.4335
# step 1280: train loss 4.2530, val loss 4.3288
# step 1290: train loss 4.1986, val loss 4.3919
# step 1300: train loss 4.2755, val loss 4.4402
# step 1310: train loss 4.2073, val loss 4.3946
# step 1320: train loss 4.2404, val loss 4.4280
# step 1330: train loss 4.1415, val loss 4.4029
# step 1340: train loss 4.1718, val loss 4.3403
# step 1350: train loss 4.1085, val loss 4.3760
# step 1360: train loss 4.1936, val loss 4.2232
# step 1370: train loss 4.1102, val loss 4.3681
# step 1380: train loss 4.1512, val loss 4.2271
# step 1390: train loss 4.1054, val loss 4.3429
# step 1400: train loss 4.1261, val loss 4.2139
# step 1410: train loss 4.0654, val loss 4.3053
# step 1420: train loss 4.1728, val loss 4.3221
# step 1430: train loss 4.1429, val loss 4.3043
# step 1440: train loss 4.1096, val loss 4.1898
# step 1450: train loss 4.1100, val loss 4.4481
# step 1460: train loss 4.1062, val loss 4.3134
# step 1470: train loss 4.1492, val loss 4.3552
# step 1480: train loss 4.0816, val loss 4.2822
# step 1490: train loss 4.1791, val loss 4.2284
# step 1500: train loss 4.0986, val loss 4.3657
# step 1510: train loss 4.0806, val loss 4.1537
# step 1520: train loss 4.0798, val loss 4.1723
# step 1530: train loss 4.0561, val loss 4.2134
# step 1540: train loss 4.1470, val loss 4.3320
# step 1550: train loss 4.0606, val loss 4.1479
# step 1560: train loss 4.0410, val loss 4.2696
# step 1570: train loss 4.0561, val loss 4.4072
# step 1580: train loss 4.0223, val loss 4.0988
# step 1590: train loss 3.9836, val loss 4.1580
# step 1600: train loss 4.0693, val loss 4.2700
# step 1610: train loss 4.0575, val loss 4.1849
# step 1620: train loss 4.0041, val loss 4.1638
# step 1630: train loss 4.0369, val loss 4.1871
# step 1640: train loss 4.0224, val loss 4.3039
# step 1650: train loss 3.9765, val loss 4.0966
# step 1660: train loss 4.0369, val loss 4.1637
# step 1670: train loss 3.9765, val loss 4.1861
# step 1680: train loss 3.9428, val loss 4.0556
# step 1690: train loss 3.9060, val loss 4.0303
# step 1700: train loss 3.9875, val loss 4.2042
# step 1710: train loss 4.0303, val loss 4.2030
# step 1720: train loss 4.0073, val loss 4.2021
# step 1730: train loss 3.9782, val loss 4.1913
# step 1740: train loss 3.9305, val loss 4.1134
# step 1750: train loss 4.0115, val loss 4.0477
# step 1760: train loss 4.0060, val loss 4.0382
# step 1770: train loss 3.9319, val loss 4.0800
# step 1780: train loss 3.9181, val loss 4.0274
# step 1790: train loss 3.9628, val loss 4.1426
# step 1800: train loss 3.8953, val loss 4.0074
# step 1810: train loss 3.8197, val loss 4.2250
# step 1820: train loss 3.8726, val loss 4.0203
# step 1830: train loss 3.9073, val loss 4.0482
# step 1840: train loss 3.9147, val loss 4.2352
# step 1850: train loss 3.9298, val loss 4.1636
# step 1860: train loss 3.8337, val loss 4.1279
# step 1870: train loss 3.8303, val loss 4.0904
# step 1880: train loss 3.9163, val loss 3.9987
# step 1890: train loss 3.8840, val loss 4.0277
# step 1900: train loss 3.8087, val loss 4.0605
# step 1910: train loss 3.7610, val loss 3.9560
# step 1920: train loss 3.8460, val loss 4.0446
# step 1930: train loss 3.8068, val loss 3.9787
# step 1940: train loss 3.8313, val loss 4.0929
# step 1950: train loss 3.8596, val loss 3.9201
# step 1960: train loss 3.7727, val loss 3.8839
# step 1970: train loss 3.8505, val loss 3.9610
# step 1980: train loss 3.7730, val loss 4.0677
# step 1990: train loss 3.8187, val loss 3.8634
# step 2000: train loss 3.7851, val loss 4.0605
# step 2010: train loss 3.8279, val loss 4.0227
# step 2020: train loss 3.8365, val loss 4.1197
# step 2030: train loss 3.8245, val loss 3.9755
# step 2040: train loss 3.8235, val loss 4.0484
# step 2050: train loss 3.8257, val loss 3.9806
# step 2060: train loss 3.7618, val loss 3.9407
# step 2070: train loss 3.7622, val loss 3.9327
# step 2080: train loss 3.7109, val loss 3.9399
# step 2090: train loss 3.8112, val loss 3.9986
# step 2100: train loss 3.7334, val loss 3.9888
# step 2110: train loss 3.7313, val loss 4.0508
# step 2120: train loss 3.7106, val loss 4.0386
# step 2130: train loss 3.7153, val loss 3.9672
# step 2140: train loss 3.7689, val loss 3.9185
# step 2150: train loss 3.7182, val loss 3.9639
# step 2160: train loss 3.7712, val loss 3.8813
# step 2170: train loss 3.7132, val loss 3.9530
# step 2180: train loss 3.6872, val loss 3.9012
# step 2190: train loss 3.7391, val loss 3.9598
# step 2200: train loss 3.6707, val loss 3.7988
# step 2210: train loss 3.7097, val loss 3.9762
# step 2220: train loss 3.6737, val loss 3.8419
# step 2230: train loss 3.7662, val loss 3.8219
# step 2240: train loss 3.6119, val loss 3.8282
# step 2250: train loss 3.6506, val loss 3.8469
# step 2260: train loss 3.6851, val loss 3.9705
# step 2270: train loss 3.7289, val loss 3.9407
# step 2280: train loss 3.6950, val loss 3.9399
# step 2290: train loss 3.6539, val loss 3.9238
# step 2300: train loss 3.7248, val loss 3.7424
# step 2310: train loss 3.6570, val loss 3.9162
# step 2320: train loss 3.6040, val loss 3.9929
# step 2330: train loss 3.6691, val loss 3.8737
# step 2340: train loss 3.6177, val loss 3.9179
# step 2350: train loss 3.7434, val loss 4.0309
# step 2360: train loss 3.7169, val loss 3.8208
# step 2370: train loss 3.5952, val loss 3.8697
# step 2380: train loss 3.7054, val loss 3.7831
# step 2390: train loss 3.6552, val loss 3.8446
# step 2400: train loss 3.5808, val loss 3.8214
# step 2410: train loss 3.6940, val loss 3.9428
# step 2420: train loss 3.5913, val loss 3.7298
# step 2430: train loss 3.7476, val loss 3.7773
# step 2440: train loss 3.6095, val loss 3.7631
# step 2450: train loss 3.5357, val loss 3.7956
# step 2460: train loss 3.5759, val loss 3.8040
# step 2470: train loss 3.5896, val loss 3.8388
# step 2480: train loss 3.5883, val loss 3.7147
# step 2490: train loss 3.6920, val loss 3.8260
# step 2500: train loss 3.5621, val loss 3.8242
# step 2510: train loss 3.5503, val loss 3.7866
# step 2520: train loss 3.5685, val loss 3.7418
# step 2530: train loss 3.5700, val loss 3.8083
# step 2540: train loss 3.6419, val loss 3.6429
# step 2550: train loss 3.5045, val loss 3.7431
# step 2560: train loss 3.5667, val loss 3.6461
# step 2570: train loss 3.5572, val loss 3.6371
# step 2580: train loss 3.5636, val loss 3.7438
# step 2590: train loss 3.5690, val loss 3.7145
# step 2600: train loss 3.5392, val loss 3.7722
# step 2610: train loss 3.6003, val loss 3.6542
# step 2620: train loss 3.5920, val loss 3.7132
# step 2630: train loss 3.5939, val loss 3.7028
# step 2640: train loss 3.5361, val loss 3.8170
# step 2650: train loss 3.5198, val loss 3.6483
# step 2660: train loss 3.5829, val loss 3.7265
# step 2670: train loss 3.5007, val loss 3.6176
# step 2680: train loss 3.5272, val loss 3.7804
# step 2690: train loss 3.4374, val loss 3.6466
# step 2700: train loss 3.5377, val loss 3.6186
# step 2710: train loss 3.4678, val loss 3.7224
# step 2720: train loss 3.6111, val loss 3.6817
# step 2730: train loss 3.5720, val loss 3.6958
# step 2740: train loss 3.4719, val loss 3.7228
# step 2750: train loss 3.5247, val loss 3.7161
# step 2760: train loss 3.5358, val loss 3.6078
# step 2770: train loss 3.5023, val loss 3.6049
# step 2780: train loss 3.4026, val loss 3.6389
# step 2790: train loss 3.4458, val loss 3.7333
# step 2800: train loss 3.4161, val loss 3.7196
# step 2810: train loss 3.4486, val loss 3.6982
# step 2820: train loss 3.5443, val loss 3.6096
# step 2830: train loss 3.4971, val loss 3.6826
# step 2840: train loss 3.3988, val loss 3.7227
# step 2850: train loss 3.4130, val loss 3.6191
# step 2860: train loss 3.3892, val loss 3.6436
# step 2870: train loss 3.3902, val loss 3.7209
# step 2880: train loss 3.3878, val loss 3.7160
# step 2890: train loss 3.4391, val loss 3.6202
# step 2900: train loss 3.3734, val loss 3.7733
# step 2910: train loss 3.4621, val loss 3.8777
# step 2920: train loss 3.5128, val loss 3.6425
# step 2930: train loss 3.3171, val loss 3.5196
# step 2940: train loss 3.4146, val loss 3.4773
# step 2950: train loss 3.5037, val loss 3.5592
# step 2960: train loss 3.4883, val loss 3.6480
# step 2970: train loss 3.4000, val loss 3.6071
# step 2980: train loss 3.4288, val loss 3.5400
# step 2990: train loss 3.3577, val loss 3.6298
# step 3000: train loss 3.3571, val loss 3.6037
# step 3010: train loss 3.4515, val loss 3.5551
# step 3020: train loss 3.3889, val loss 3.5566
# step 3030: train loss 3.3044, val loss 3.5999
# step 3040: train loss 3.3975, val loss 3.6502
# step 3050: train loss 3.4112, val loss 3.6256
# step 3060: train loss 3.2936, val loss 3.7660
# step 3070: train loss 3.3099, val loss 3.6488
# step 3080: train loss 3.3173, val loss 3.4919
# step 3090: train loss 3.3774, val loss 3.6060
# step 3100: train loss 3.3662, val loss 3.5593
# step 3110: train loss 3.3321, val loss 3.5753
# step 3120: train loss 3.2634, val loss 3.5505
# step 3130: train loss 3.3101, val loss 3.5394
# step 3140: train loss 3.2836, val loss 3.6090
# step 3150: train loss 3.2372, val loss 3.5609
# step 3160: train loss 3.2629, val loss 3.5983
# step 3170: train loss 3.3031, val loss 3.5205
# step 3180: train loss 3.3086, val loss 3.4278
# step 3190: train loss 3.3629, val loss 3.6079
# step 3200: train loss 3.2767, val loss 3.5950
# step 3210: train loss 3.3175, val loss 3.4914
# step 3220: train loss 3.2715, val loss 3.6361
# step 3230: train loss 3.3390, val loss 3.3298
# step 3240: train loss 3.3189, val loss 3.5269
# step 3250: train loss 3.2639, val loss 3.4634
# step 3260: train loss 3.2579, val loss 3.4677
# step 3270: train loss 3.2369, val loss 3.6014
# step 3280: train loss 3.2631, val loss 3.5186
# step 3290: train loss 3.2917, val loss 3.5398
# step 3300: train loss 3.2629, val loss 3.5745
# step 3310: train loss 3.2274, val loss 3.4601
# step 3320: train loss 3.3056, val loss 3.5663
# step 3330: train loss 3.2401, val loss 3.6409
# step 3340: train loss 3.2726, val loss 3.4102
# step 3350: train loss 3.2274, val loss 3.3903
# step 3360: train loss 3.3035, val loss 3.4401
# step 3370: train loss 3.2765, val loss 3.4530
# step 3380: train loss 3.2862, val loss 3.3719
# step 3390: train loss 3.3089, val loss 3.4548
# step 3400: train loss 3.1898, val loss 3.4467
# step 3410: train loss 3.2979, val loss 3.4937
# step 3420: train loss 3.3134, val loss 3.4944
# step 3430: train loss 3.1960, val loss 3.4242
# step 3440: train loss 3.1497, val loss 3.4740
# step 3450: train loss 3.2136, val loss 3.3599
# step 3460: train loss 3.2388, val loss 3.5044
# step 3470: train loss 3.2521, val loss 3.3978
# step 3480: train loss 3.2743, val loss 3.4314
# step 3490: train loss 3.2848, val loss 3.3834
# step 3500: train loss 3.1356, val loss 3.4282
# step 3510: train loss 3.2074, val loss 3.4094
# step 3520: train loss 3.1464, val loss 3.4912
# step 3530: train loss 3.1453, val loss 3.4039
# step 3540: train loss 3.2003, val loss 3.4514
# step 3550: train loss 3.2775, val loss 3.4367
# step 3560: train loss 3.2851, val loss 3.3671
# step 3570: train loss 3.1839, val loss 3.5759
# step 3580: train loss 3.1942, val loss 3.4243
# step 3590: train loss 3.2411, val loss 3.3861
# step 3600: train loss 3.1995, val loss 3.4306
# step 3610: train loss 3.1955, val loss 3.2402
# step 3620: train loss 3.1897, val loss 3.2753
# step 3630: train loss 3.1877, val loss 3.5813
# step 3640: train loss 3.2155, val loss 3.4577
# step 3650: train loss 3.1682, val loss 3.5192
# step 3660: train loss 3.2028, val loss 3.4278
# step 3670: train loss 3.1929, val loss 3.5021
# step 3680: train loss 3.1799, val loss 3.1939
# step 3690: train loss 3.2237, val loss 3.3319
# step 3700: train loss 3.1902, val loss 3.3428
# step 3710: train loss 3.1463, val loss 3.3645
# step 3720: train loss 3.2144, val loss 3.3515
# step 3730: train loss 3.1958, val loss 3.2153
# step 3740: train loss 3.1574, val loss 3.4224
# step 3750: train loss 3.1140, val loss 3.5035
# step 3760: train loss 3.1264, val loss 3.3228
# step 3770: train loss 3.1358, val loss 3.2522
# step 3780: train loss 3.1256, val loss 3.2034
# step 3790: train loss 3.0982, val loss 3.4930
# step 3800: train loss 3.1624, val loss 3.5268
# step 3810: train loss 3.0436, val loss 3.2134
# step 3820: train loss 3.1010, val loss 3.3858
# step 3830: train loss 3.0393, val loss 3.4421
# step 3840: train loss 3.1864, val loss 3.3357
# step 3850: train loss 3.1719, val loss 3.3682
# step 3860: train loss 3.1487, val loss 3.3348
# step 3870: train loss 3.1448, val loss 3.4495
# step 3880: train loss 3.1193, val loss 3.3471
# step 3890: train loss 3.0915, val loss 3.3718
# step 3900: train loss 3.1095, val loss 3.3658
# step 3910: train loss 2.9898, val loss 3.2015
# step 3920: train loss 3.1288, val loss 3.3723
# step 3930: train loss 3.1552, val loss 3.3378
# step 3940: train loss 3.0938, val loss 3.3652
# step 3950: train loss 3.0654, val loss 3.3804
# step 3960: train loss 3.0306, val loss 3.3290
# step 3970: train loss 3.1065, val loss 3.3554
# step 3980: train loss 3.0573, val loss 3.2841
# step 3990: train loss 3.1084, val loss 3.2721
# step 4000: train loss 2.9913, val loss 3.3595
# step 4010: train loss 3.0706, val loss 3.2967
# step 4020: train loss 3.0389, val loss 3.3096
# step 4030: train loss 3.0572, val loss 3.3761
# step 4040: train loss 3.0220, val loss 3.2272
# step 4050: train loss 3.0790, val loss 3.3370
# step 4060: train loss 3.0978, val loss 3.3498
# step 4070: train loss 3.1237, val loss 3.1186
# step 4080: train loss 3.0465, val loss 3.1926
# step 4090: train loss 3.0958, val loss 3.2261
# step 4100: train loss 2.9872, val loss 3.4727
# step 4110: train loss 3.0679, val loss 3.2764
# step 4120: train loss 3.0541, val loss 3.2490
# step 4130: train loss 3.0583, val loss 3.3431
# step 4140: train loss 3.0544, val loss 3.2689
# step 4150: train loss 2.9474, val loss 3.1940
# step 4160: train loss 3.1061, val loss 3.2397
# step 4170: train loss 3.0053, val loss 3.3181
# step 4180: train loss 3.0315, val loss 3.2059
# step 4190: train loss 3.1038, val loss 3.2005
# step 4200: train loss 3.0489, val loss 3.2719
# step 4210: train loss 3.0608, val loss 3.2636
# step 4220: train loss 3.0291, val loss 3.2219
# step 4230: train loss 3.0572, val loss 3.2414
# step 4240: train loss 2.9409, val loss 3.2118
# step 4250: train loss 3.0664, val loss 3.2018
# step 4260: train loss 3.0228, val loss 3.2875
# step 4270: train loss 3.0001, val loss 3.2641
# step 4280: train loss 2.9956, val loss 3.2411
# step 4290: train loss 2.9978, val loss 3.2865
# step 4300: train loss 3.0088, val loss 2.9987
# step 4310: train loss 2.9800, val loss 3.2187
# step 4320: train loss 3.0608, val loss 3.2693
# step 4330: train loss 3.0232, val loss 3.2061
# step 4340: train loss 2.9781, val loss 3.2002
# step 4350: train loss 3.0459, val loss 3.2271
# step 4360: train loss 3.0479, val loss 3.1979
# step 4370: train loss 3.0971, val loss 3.1834
# step 4380: train loss 3.0255, val loss 3.1308
# step 4390: train loss 3.0329, val loss 3.2224
# step 4400: train loss 2.9989, val loss 3.1053
# step 4410: train loss 2.9946, val loss 3.2153
# step 4420: train loss 2.9433, val loss 3.1678
# step 4430: train loss 3.0783, val loss 3.1961
# step 4440: train loss 2.9881, val loss 3.1522
# step 4450: train loss 2.9438, val loss 3.2923
# step 4460: train loss 2.9603, val loss 3.2971
# step 4470: train loss 2.9580, val loss 3.2986
# step 4480: train loss 3.0357, val loss 3.3157
# step 4490: train loss 3.0021, val loss 3.0734
# step 4500: train loss 2.8785, val loss 3.1778
# step 4510: train loss 3.0114, val loss 3.0855
# step 4520: train loss 2.8879, val loss 3.1163
# step 4530: train loss 2.8808, val loss 3.2326
# step 4540: train loss 2.8662, val loss 3.1789
# step 4550: train loss 2.9528, val loss 3.1003
# step 4560: train loss 2.9924, val loss 3.1561
# step 4570: train loss 2.9347, val loss 3.1934
# step 4580: train loss 2.8915, val loss 3.1065
# step 4590: train loss 3.0103, val loss 3.2838
# step 4600: train loss 3.0274, val loss 3.1602
# step 4610: train loss 3.0012, val loss 3.1236
# step 4620: train loss 2.9520, val loss 3.1669
# step 4630: train loss 2.9769, val loss 3.1317
# step 4640: train loss 2.8486, val loss 2.9269
# step 4650: train loss 2.9910, val loss 3.3018
# step 4660: train loss 2.9320, val loss 3.1792
# step 4670: train loss 2.9871, val loss 3.0556
# step 4680: train loss 2.9838, val loss 3.1251
# step 4690: train loss 2.8769, val loss 3.0824
# step 4700: train loss 2.9425, val loss 3.1551
# step 4710: train loss 2.9420, val loss 3.1106
# step 4720: train loss 2.9206, val loss 3.0315
# step 4730: train loss 2.8871, val loss 3.1849
# step 4740: train loss 3.0416, val loss 3.0172
# step 4750: train loss 2.8540, val loss 3.1990
# step 4760: train loss 2.8848, val loss 3.1839
# step 4770: train loss 2.9346, val loss 3.0984
# step 4780: train loss 2.9940, val loss 3.1089
# step 4790: train loss 2.9590, val loss 3.1028
# step 4800: train loss 2.9232, val loss 3.2023
# step 4810: train loss 2.8741, val loss 3.0941
# step 4820: train loss 2.8850, val loss 3.0662
# step 4830: train loss 2.8670, val loss 3.0571
# step 4840: train loss 2.9411, val loss 3.2077
# step 4850: train loss 2.9582, val loss 3.0340
# step 4860: train loss 2.8936, val loss 3.0523
# step 4870: train loss 2.8233, val loss 3.0547
# step 4880: train loss 2.9137, val loss 3.1140
# step 4890: train loss 2.8788, val loss 3.0337
# step 4900: train loss 2.8928, val loss 3.1142
# step 4910: train loss 2.8432, val loss 3.0867
# step 4920: train loss 2.8215, val loss 3.1230
# step 4930: train loss 2.9427, val loss 2.9671
# step 4940: train loss 2.8978, val loss 3.0467
# step 4950: train loss 2.8747, val loss 2.9687
# step 4960: train loss 2.8826, val loss 3.1449
# step 4970: train loss 2.8946, val loss 2.9963
# step 4980: train loss 2.9586, val loss 3.0148
# step 4990: train loss 2.8195, val loss 3.1302
# step 5000: train loss 2.8427, val loss 3.0245
# step 5010: train loss 2.8441, val loss 3.0723
# step 5020: train loss 2.8566, val loss 2.9997
# step 5030: train loss 2.8585, val loss 3.1747
# step 5040: train loss 2.8589, val loss 3.0321
# step 5050: train loss 2.8751, val loss 2.9561
# step 5060: train loss 2.8781, val loss 2.9680
# step 5070: train loss 2.9325, val loss 3.2098
# step 5080: train loss 2.8612, val loss 3.1078
# step 5090: train loss 2.9180, val loss 3.0262
# step 5100: train loss 2.7934, val loss 3.0588
# step 5110: train loss 2.8307, val loss 3.1604
# step 5120: train loss 2.9435, val loss 3.0198
# step 5130: train loss 2.8037, val loss 2.9676
# step 5140: train loss 2.8392, val loss 3.1537
# step 5150: train loss 2.7973, val loss 3.1337
# step 5160: train loss 2.8720, val loss 3.1214
# step 5170: train loss 2.8982, val loss 3.1234
# step 5180: train loss 2.9230, val loss 3.0763
# step 5190: train loss 2.8528, val loss 2.9866
# step 5200: train loss 2.7843, val loss 3.0093
# step 5210: train loss 2.8579, val loss 3.2134
# step 5220: train loss 2.8325, val loss 3.0305
# step 5230: train loss 2.8865, val loss 2.9631
# step 5240: train loss 2.8032, val loss 3.1955
# step 5250: train loss 2.8437, val loss 3.0563
# step 5260: train loss 2.8859, val loss 3.1034
# step 5270: train loss 2.8669, val loss 3.1500
# step 5280: train loss 2.8348, val loss 3.0251
# step 5290: train loss 2.7551, val loss 2.8748
# step 5300: train loss 2.8128, val loss 2.9864
# step 5310: train loss 2.8135, val loss 2.9411
# step 5320: train loss 2.7590, val loss 3.0426
# step 5330: train loss 2.7217, val loss 2.9585
# step 5340: train loss 2.7214, val loss 3.0556
# step 5350: train loss 2.7261, val loss 3.0418
# step 5360: train loss 2.8364, val loss 3.0700
# step 5370: train loss 2.7117, val loss 2.9130
# step 5380: train loss 2.8367, val loss 2.9015
# step 5390: train loss 2.8129, val loss 3.0922
# step 5400: train loss 2.8510, val loss 2.8431
# step 5410: train loss 2.7881, val loss 3.1074
# step 5420: train loss 2.8768, val loss 2.9448
# step 5430: train loss 2.8334, val loss 3.1216
# step 5440: train loss 2.7352, val loss 3.0002
# step 5450: train loss 2.7539, val loss 3.0732
# step 5460: train loss 2.8191, val loss 2.9900
# step 5470: train loss 2.7905, val loss 2.9382
# step 5480: train loss 2.8219, val loss 3.1575
# step 5490: train loss 2.8501, val loss 3.0992
# step 5500: train loss 2.7963, val loss 3.0015
# step 5510: train loss 2.8491, val loss 2.8717
# step 5520: train loss 2.8008, val loss 2.8969
# step 5530: train loss 2.8461, val loss 3.0939
# step 5540: train loss 2.8396, val loss 2.9123
# step 5550: train loss 2.8005, val loss 2.9878
# step 5560: train loss 2.7272, val loss 3.0746
# step 5570: train loss 2.7882, val loss 2.9229
# step 5580: train loss 2.8352, val loss 3.1203
# step 5590: train loss 2.8362, val loss 2.9858
# step 5600: train loss 2.8302, val loss 2.8735
# step 5610: train loss 2.7869, val loss 2.9980
# step 5620: train loss 2.8880, val loss 3.1039
# step 5630: train loss 2.7870, val loss 3.0841
# step 5640: train loss 2.6417, val loss 2.9499
# step 5650: train loss 2.7506, val loss 3.0175
# step 5660: train loss 2.7506, val loss 3.0817
# step 5670: train loss 2.7897, val loss 2.9193
# step 5680: train loss 2.7995, val loss 3.0065
# step 5690: train loss 2.7166, val loss 3.0249
# step 5700: train loss 2.7550, val loss 2.9222
# step 5710: train loss 2.7823, val loss 2.9527
# step 5720: train loss 2.8765, val loss 2.8495
# step 5730: train loss 2.7470, val loss 2.9760
# step 5740: train loss 2.7121, val loss 2.9179
# step 5750: train loss 2.7154, val loss 2.9480
# step 5760: train loss 2.7429, val loss 2.9458
# step 5770: train loss 2.7287, val loss 2.9642
# step 5780: train loss 2.8278, val loss 2.9708
# step 5790: train loss 2.8399, val loss 3.1368
# step 5800: train loss 2.7700, val loss 3.0133
# step 5810: train loss 2.7749, val loss 2.9274
# step 5820: train loss 2.7491, val loss 3.0655
# step 5830: train loss 2.7536, val loss 2.8573
# step 5840: train loss 2.7239, val loss 3.0259
# step 5850: train loss 2.7828, val loss 2.8986
# step 5860: train loss 2.6998, val loss 2.8744
# step 5870: train loss 2.7998, val loss 2.9334
# step 5880: train loss 2.7206, val loss 3.0101
# step 5890: train loss 2.7755, val loss 2.9403
# step 5900: train loss 2.7488, val loss 3.0033
# step 5910: train loss 2.7575, val loss 2.9492
# step 5920: train loss 2.8334, val loss 2.9315
# step 5930: train loss 2.7225, val loss 2.8530
# step 5940: train loss 2.7496, val loss 2.8959
# step 5950: train loss 2.7450, val loss 2.9522
# step 5960: train loss 2.7703, val loss 2.9724
# step 5970: train loss 2.7273, val loss 2.8678
# step 5980: train loss 2.7183, val loss 3.0526
# step 5990: train loss 2.7176, val loss 3.0217
# step 6000: train loss 2.8309, val loss 3.0376
# step 6010: train loss 2.7499, val loss 2.9312
# step 6020: train loss 2.6691, val loss 2.8608
# step 6030: train loss 2.8951, val loss 2.9819
# step 6040: train loss 2.7713, val loss 2.8273
# step 6050: train loss 2.7454, val loss 2.9553
# step 6060: train loss 2.7078, val loss 2.8795
# step 6070: train loss 2.7699, val loss 2.9541
# step 6080: train loss 2.8141, val loss 2.8702
# step 6090: train loss 2.7542, val loss 2.7992
# step 6100: train loss 2.7145, val loss 2.8523
# step 6110: train loss 2.6988, val loss 2.9472
# step 6120: train loss 2.7686, val loss 2.9304
# step 6130: train loss 2.6667, val loss 2.8831
# step 6140: train loss 2.8174, val loss 2.9615
# step 6150: train loss 2.7784, val loss 2.9070
# step 6160: train loss 2.6148, val loss 2.9818
# step 6170: train loss 2.7043, val loss 2.9053
# step 6180: train loss 2.7397, val loss 2.8289
# step 6190: train loss 2.7681, val loss 2.8888
# step 6200: train loss 2.7223, val loss 2.9596
# step 6210: train loss 2.6723, val loss 2.9346
# step 6220: train loss 2.7408, val loss 2.8852
# step 6230: train loss 2.7657, val loss 2.8744
# step 6240: train loss 2.7408, val loss 2.8059
# step 6250: train loss 2.7420, val loss 2.8518
# step 6260: train loss 2.6968, val loss 2.9549
# step 6270: train loss 2.7559, val loss 2.8012
# step 6280: train loss 2.7545, val loss 2.9414
# step 6290: train loss 2.6977, val loss 2.9023
# step 6300: train loss 2.6746, val loss 2.8933
# step 6310: train loss 2.6858, val loss 2.7979
# step 6320: train loss 2.7431, val loss 2.8835
# step 6330: train loss 2.6913, val loss 2.8635
# step 6340: train loss 2.7304, val loss 2.9365
# step 6350: train loss 2.7657, val loss 2.7823
# step 6360: train loss 2.7768, val loss 2.8387
# step 6370: train loss 2.7370, val loss 2.8347
# step 6380: train loss 2.7338, val loss 2.8042
# step 6390: train loss 2.7021, val loss 2.8619
# step 6400: train loss 2.8349, val loss 2.8581
# step 6410: train loss 2.6889, val loss 2.7384
# step 6420: train loss 2.6874, val loss 2.9342
# step 6430: train loss 2.7007, val loss 2.9195
# step 6440: train loss 2.6560, val loss 2.9227
# step 6450: train loss 2.7680, val loss 2.8345
# step 6460: train loss 2.6420, val loss 2.8358
# step 6470: train loss 2.6772, val loss 2.7996
# step 6480: train loss 2.7139, val loss 2.8886
# step 6490: train loss 2.7559, val loss 2.8421
# step 6500: train loss 2.7527, val loss 2.8861
# step 6510: train loss 2.6902, val loss 2.8527
# step 6520: train loss 2.7542, val loss 2.8826
# step 6530: train loss 2.7783, val loss 2.8356
# step 6540: train loss 2.7931, val loss 2.9806
# step 6550: train loss 2.6930, val loss 2.8533
# step 6560: train loss 2.6937, val loss 2.8683
# step 6570: train loss 2.7043, val loss 2.8341
# step 6580: train loss 2.6477, val loss 2.9970
# step 6590: train loss 2.6887, val loss 2.9114
# step 6600: train loss 2.7411, val loss 2.8449
# step 6610: train loss 2.7394, val loss 2.8225
# step 6620: train loss 2.7514, val loss 2.8000
# step 6630: train loss 2.6573, val loss 2.7575
# step 6640: train loss 2.7738, val loss 3.0473
# step 6650: train loss 2.7046, val loss 2.8395
# step 6660: train loss 2.6183, val loss 2.8951
# step 6670: train loss 2.6803, val loss 2.8840
# step 6680: train loss 2.7001, val loss 2.7434
# step 6690: train loss 2.6861, val loss 2.7479
# step 6700: train loss 2.6394, val loss 2.8410
# step 6710: train loss 2.5862, val loss 2.8140
# step 6720: train loss 2.6299, val loss 2.7794
# step 6730: train loss 2.7764, val loss 2.6887
# step 6740: train loss 2.7360, val loss 2.8639
# step 6750: train loss 2.7212, val loss 2.9257
# step 6760: train loss 2.8331, val loss 2.8205
# step 6770: train loss 2.7405, val loss 2.7236
# step 6780: train loss 2.6359, val loss 2.8525
# step 6790: train loss 2.6803, val loss 2.8542
# step 6800: train loss 2.6626, val loss 2.8700
# step 6810: train loss 2.7481, val loss 2.8852
# step 6820: train loss 2.5682, val loss 2.6927
# step 6830: train loss 2.7104, val loss 2.9438
# step 6840: train loss 2.7007, val loss 2.7794
# step 6850: train loss 2.6323, val loss 2.8096
# step 6860: train loss 2.6889, val loss 2.8458
# step 6870: train loss 2.6733, val loss 2.7092
# step 6880: train loss 2.6656, val loss 2.7912
# step 6890: train loss 2.6382, val loss 2.8086
# step 6900: train loss 2.6605, val loss 2.7632
# step 6910: train loss 2.5813, val loss 2.8311
# step 6920: train loss 2.6588, val loss 2.8276
# step 6930: train loss 2.6814, val loss 2.8528
# step 6940: train loss 2.7348, val loss 2.9026
# step 6950: train loss 2.6266, val loss 2.8647
# step 6960: train loss 2.5632, val loss 2.8507
# step 6970: train loss 2.6407, val loss 2.6961
# step 6980: train loss 2.7253, val loss 2.8459
# step 6990: train loss 2.6686, val loss 2.7564
# step 7000: train loss 2.6393, val loss 2.8795
# step 7010: train loss 2.6525, val loss 2.9247
# step 7020: train loss 2.5954, val loss 2.9505
# step 7030: train loss 2.6694, val loss 2.9084
# step 7040: train loss 2.6708, val loss 2.8695
# step 7050: train loss 2.6815, val loss 2.8017
# step 7060: train loss 2.6202, val loss 2.8388
# step 7070: train loss 2.5723, val loss 2.7814
# step 7080: train loss 2.6313, val loss 2.8782
# step 7090: train loss 2.6282, val loss 2.8261
# step 7100: train loss 2.6900, val loss 2.8142
# step 7110: train loss 2.5801, val loss 2.8152
# step 7120: train loss 2.5591, val loss 2.9032
# step 7130: train loss 2.6865, val loss 2.9491
# step 7140: train loss 2.6199, val loss 2.8271
# step 7150: train loss 2.6675, val loss 2.7003
# step 7160: train loss 2.6216, val loss 2.8970
# step 7170: train loss 2.6600, val loss 2.6293
# step 7180: train loss 2.6820, val loss 2.8285
# step 7190: train loss 2.5898, val loss 2.8121
# step 7200: train loss 2.7639, val loss 2.8311
# step 7210: train loss 2.7121, val loss 2.8412
# step 7220: train loss 2.5884, val loss 2.6813
# step 7230: train loss 2.6077, val loss 2.8471
# step 7240: train loss 2.5692, val loss 2.7579
# step 7250: train loss 2.5926, val loss 2.7920
# step 7260: train loss 2.6205, val loss 2.7871
# step 7270: train loss 2.6714, val loss 2.8783
# step 7280: train loss 2.6500, val loss 2.8685
# step 7290: train loss 2.6577, val loss 2.9199
# step 7300: train loss 2.5977, val loss 2.8835
# step 7310: train loss 2.6275, val loss 2.9470
# step 7320: train loss 2.6730, val loss 2.9091
# step 7330: train loss 2.6587, val loss 2.7133
# step 7340: train loss 2.6562, val loss 2.8148
# step 7350: train loss 2.6645, val loss 2.8421
# step 7360: train loss 2.5548, val loss 2.8488
# step 7370: train loss 2.6240, val loss 2.8258
# step 7380: train loss 2.7375, val loss 2.7814
# step 7390: train loss 2.6166, val loss 2.7200
# step 7400: train loss 2.6852, val loss 2.7125
# step 7410: train loss 2.6194, val loss 2.7864
# step 7420: train loss 2.6085, val loss 2.8386
# step 7430: train loss 2.6328, val loss 2.8365
# step 7440: train loss 2.6598, val loss 2.7597
# step 7450: train loss 2.6435, val loss 2.7966
# step 7460: train loss 2.6104, val loss 2.8098
# step 7470: train loss 2.6521, val loss 2.7700
# step 7480: train loss 2.6215, val loss 2.8123
# step 7490: train loss 2.6394, val loss 2.8200
# step 7500: train loss 2.6817, val loss 2.7804
# step 7510: train loss 2.6832, val loss 2.7344
# step 7520: train loss 2.6641, val loss 2.7846
# step 7530: train loss 2.6265, val loss 2.8343
# step 7540: train loss 2.6063, val loss 2.7442
# step 7550: train loss 2.6233, val loss 2.7927
# step 7560: train loss 2.6203, val loss 2.6791
# step 7570: train loss 2.6460, val loss 2.8454
# step 7580: train loss 2.6247, val loss 2.7578
# step 7590: train loss 2.6647, val loss 2.7009
# step 7600: train loss 2.5956, val loss 2.7803
# step 7610: train loss 2.5549, val loss 2.6962
# step 7620: train loss 2.6384, val loss 2.7756
# step 7630: train loss 2.5911, val loss 2.7751
# step 7640: train loss 2.5512, val loss 2.7812
# step 7650: train loss 2.6419, val loss 2.6858
# step 7660: train loss 2.6659, val loss 2.7315
# step 7670: train loss 2.5933, val loss 2.7488
# step 7680: train loss 2.5428, val loss 2.9162
# step 7690: train loss 2.6342, val loss 2.7598
# step 7700: train loss 2.6895, val loss 2.7119
# step 7710: train loss 2.6513, val loss 2.7949
# step 7720: train loss 2.6356, val loss 2.7871
# step 7730: train loss 2.6254, val loss 2.7781
# step 7740: train loss 2.6119, val loss 2.6167
# step 7750: train loss 2.5456, val loss 2.8083
# step 7760: train loss 2.7098, val loss 2.7758
# step 7770: train loss 2.6632, val loss 2.7037
# step 7780: train loss 2.5850, val loss 2.8799
# step 7790: train loss 2.6579, val loss 2.6734
# step 7800: train loss 2.5442, val loss 2.6680
# step 7810: train loss 2.5719, val loss 2.7518
# step 7820: train loss 2.6361, val loss 2.7982
# step 7830: train loss 2.5823, val loss 2.6854
# step 7840: train loss 2.5571, val loss 2.6991
# step 7850: train loss 2.5656, val loss 2.5214
# step 7860: train loss 2.5961, val loss 2.7392
# step 7870: train loss 2.4923, val loss 2.6813
# step 7880: train loss 2.6669, val loss 2.7902
# step 7890: train loss 2.5608, val loss 2.7413
# step 7900: train loss 2.5798, val loss 2.6842
# step 7910: train loss 2.6146, val loss 2.8147
# step 7920: train loss 2.5620, val loss 2.7738
# step 7930: train loss 2.7484, val loss 2.6570
# step 7940: train loss 2.6286, val loss 2.8352
# step 7950: train loss 2.5092, val loss 2.7507
# step 7960: train loss 2.7127, val loss 2.7236
# step 7970: train loss 2.4790, val loss 2.6589
# step 7980: train loss 2.6296, val loss 2.7364
# step 7990: train loss 2.5529, val loss 2.7287
# step 8000: train loss 2.5358, val loss 2.7531
# step 8010: train loss 2.5173, val loss 2.8499
# step 8020: train loss 2.5929, val loss 2.7750
# step 8030: train loss 2.5901, val loss 2.7167
# step 8040: train loss 2.4609, val loss 2.7128
# step 8050: train loss 2.5575, val loss 2.7853
# step 8060: train loss 2.6431, val loss 2.8192
# step 8070: train loss 2.5865, val loss 2.7990
# step 8080: train loss 2.5854, val loss 2.6439
# step 8090: train loss 2.5978, val loss 2.7217
# step 8100: train loss 2.5692, val loss 2.6410
# step 8110: train loss 2.5849, val loss 2.7086
# step 8120: train loss 2.5923, val loss 2.8860
# step 8130: train loss 2.6510, val loss 2.7670
# step 8140: train loss 2.5405, val loss 2.7516
# step 8150: train loss 2.4579, val loss 2.6537
# step 8160: train loss 2.6091, val loss 2.7513
# step 8170: train loss 2.5336, val loss 2.7882
# step 8180: train loss 2.6153, val loss 2.6899
# step 8190: train loss 2.5961, val loss 2.8167
# step 8200: train loss 2.6135, val loss 2.6249
# step 8210: train loss 2.6434, val loss 2.6916
# step 8220: train loss 2.6256, val loss 2.7425
# step 8230: train loss 2.5369, val loss 2.7468
# step 8240: train loss 2.5991, val loss 2.7668
# step 8250: train loss 2.5392, val loss 2.7227
# step 8260: train loss 2.5630, val loss 2.7053
# step 8270: train loss 2.5842, val loss 2.6615
# step 8280: train loss 2.6081, val loss 2.7353
# step 8290: train loss 2.5194, val loss 2.7338
# step 8300: train loss 2.5623, val loss 2.7065
# step 8310: train loss 2.6449, val loss 2.7315
# step 8320: train loss 2.5661, val loss 2.7014
# step 8330: train loss 2.4871, val loss 2.6952
# step 8340: train loss 2.5485, val loss 2.6826
# step 8350: train loss 2.5388, val loss 2.6451
# step 8360: train loss 2.5822, val loss 2.7418
# step 8370: train loss 2.5889, val loss 2.6966
# step 8380: train loss 2.6154, val loss 2.6972
# step 8390: train loss 2.5682, val loss 2.6457
# step 8400: train loss 2.4851, val loss 2.7064
# step 8410: train loss 2.5511, val loss 2.7825
# step 8420: train loss 2.5203, val loss 2.6777
# step 8430: train loss 2.5867, val loss 2.7923
# step 8440: train loss 2.5363, val loss 2.7013
# step 8450: train loss 2.4815, val loss 2.6903
# step 8460: train loss 2.5877, val loss 2.9605
# step 8470: train loss 2.5221, val loss 2.6322
# step 8480: train loss 2.5256, val loss 2.6587
# step 8490: train loss 2.4752, val loss 2.6867
# step 8500: train loss 2.5382, val loss 2.7473
# step 8510: train loss 2.6109, val loss 2.6465
# step 8520: train loss 2.5066, val loss 2.6024
# step 8530: train loss 2.6023, val loss 2.6367
# step 8540: train loss 2.6169, val loss 2.7768
# step 8550: train loss 2.6014, val loss 2.5904
# step 8560: train loss 2.5637, val loss 2.7273
# step 8570: train loss 2.5714, val loss 2.7224
# step 8580: train loss 2.5275, val loss 2.7822
# step 8590: train loss 2.5103, val loss 2.6341
# step 8600: train loss 2.6016, val loss 2.8224
# step 8610: train loss 2.5116, val loss 2.6994
# step 8620: train loss 2.6134, val loss 2.6870
# step 8630: train loss 2.6159, val loss 2.7445
# step 8640: train loss 2.5139, val loss 2.8218
# step 8650: train loss 2.5437, val loss 2.7284
# step 8660: train loss 2.5318, val loss 2.7146
# step 8670: train loss 2.5687, val loss 2.6001
# step 8680: train loss 2.5533, val loss 2.6647
# step 8690: train loss 2.5690, val loss 2.6338
# step 8700: train loss 2.5781, val loss 2.6599
# step 8710: train loss 2.4985, val loss 2.6466
# step 8720: train loss 2.5014, val loss 2.7249
# step 8730: train loss 2.4901, val loss 2.6132
# step 8740: train loss 2.5741, val loss 2.7130
# step 8750: train loss 2.5008, val loss 2.6952
# step 8760: train loss 2.5372, val loss 2.5564
# step 8770: train loss 2.5522, val loss 2.7319
# step 8780: train loss 2.5464, val loss 2.6833
# step 8790: train loss 2.6403, val loss 2.6999
# step 8800: train loss 2.5126, val loss 2.7068
# step 8810: train loss 2.5638, val loss 2.6684
# step 8820: train loss 2.5183, val loss 2.7332
# step 8830: train loss 2.5774, val loss 2.7338
# step 8840: train loss 2.5006, val loss 2.7210
# step 8850: train loss 2.5682, val loss 2.6478
# step 8860: train loss 2.5743, val loss 2.7070
# step 8870: train loss 2.5750, val loss 2.6872
# step 8880: train loss 2.5152, val loss 2.8410
# step 8890: train loss 2.5436, val loss 2.7196
# step 8900: train loss 2.5602, val loss 2.7159
# step 8910: train loss 2.5632, val loss 2.6333
# step 8920: train loss 2.5353, val loss 2.6267
# step 8930: train loss 2.5327, val loss 2.7204
# step 8940: train loss 2.6342, val loss 2.7244
# step 8950: train loss 2.5983, val loss 2.7487
# step 8960: train loss 2.5774, val loss 2.6105
# step 8970: train loss 2.5388, val loss 2.6755
# step 8980: train loss 2.5659, val loss 2.6579
# step 8990: train loss 2.5199, val loss 2.6577
# step 9000: train loss 2.5030, val loss 2.6444
# step 9010: train loss 2.5427, val loss 2.7183
# step 9020: train loss 2.5080, val loss 2.6434
# step 9030: train loss 2.5018, val loss 2.7116
# step 9040: train loss 2.5356, val loss 2.6469
# step 9050: train loss 2.4559, val loss 2.6417
# step 9060: train loss 2.6163, val loss 2.7006
# step 9070: train loss 2.5542, val loss 2.6943
# step 9080: train loss 2.5257, val loss 2.7187
# step 9090: train loss 2.5691, val loss 2.6498
# step 9100: train loss 2.4855, val loss 2.6998
# step 9110: train loss 2.5635, val loss 2.6285
# step 9120: train loss 2.5241, val loss 2.6824
# step 9130: train loss 2.6024, val loss 2.6302
# step 9140: train loss 2.5602, val loss 2.6574
# step 9150: train loss 2.5259, val loss 2.6952
# step 9160: train loss 2.6153, val loss 2.8072
# step 9170: train loss 2.5562, val loss 2.6832
# step 9180: train loss 2.5274, val loss 2.6449
# step 9190: train loss 2.5331, val loss 2.7582
# step 9200: train loss 2.4827, val loss 2.6351
# step 9210: train loss 2.5063, val loss 2.7256
# step 9220: train loss 2.5737, val loss 2.6852
# step 9230: train loss 2.5585, val loss 2.5769
# step 9240: train loss 2.5384, val loss 2.6518
# step 9250: train loss 2.4923, val loss 2.5252
# step 9260: train loss 2.5531, val loss 2.5827
# step 9270: train loss 2.5279, val loss 2.7679
# step 9280: train loss 2.6561, val loss 2.6434
# step 9290: train loss 2.5692, val loss 2.7334
# step 9300: train loss 2.5387, val loss 2.7198
# step 9310: train loss 2.5236, val loss 2.6286
# step 9320: train loss 2.4259, val loss 2.5627
# step 9330: train loss 2.4989, val loss 2.7258
# step 9340: train loss 2.5229, val loss 2.6886
# step 9350: train loss 2.4745, val loss 2.6861
# step 9360: train loss 2.4753, val loss 2.6460
# step 9370: train loss 2.4821, val loss 2.5792
# step 9380: train loss 2.5100, val loss 2.5914
# step 9390: train loss 2.5014, val loss 2.6254
# step 9400: train loss 2.5339, val loss 2.6698
# step 9410: train loss 2.6198, val loss 2.7212
# step 9420: train loss 2.5158, val loss 2.7298
# step 9430: train loss 2.4868, val loss 2.6500
# step 9440: train loss 2.5298, val loss 2.6552
# step 9450: train loss 2.5130, val loss 2.6032
# step 9460: train loss 2.5332, val loss 2.5640
# step 9470: train loss 2.5295, val loss 2.6275
# step 9480: train loss 2.5213, val loss 2.6762
# step 9490: train loss 2.5812, val loss 2.6070
# step 9500: train loss 2.5672, val loss 2.6816
# step 9510: train loss 2.5358, val loss 2.7159
# step 9520: train loss 2.5070, val loss 2.6896
# step 9530: train loss 2.6131, val loss 2.6228
# step 9540: train loss 2.6147, val loss 2.6170
# step 9550: train loss 2.4931, val loss 2.6919
# step 9560: train loss 2.4759, val loss 2.6065
# step 9570: train loss 2.4986, val loss 2.6439
# step 9580: train loss 2.5348, val loss 2.6470
# step 9590: train loss 2.5309, val loss 2.6197
# step 9600: train loss 2.5869, val loss 2.6195
# step 9610: train loss 2.5025, val loss 2.7263
# step 9620: train loss 2.5550, val loss 2.6030
# step 9630: train loss 2.5154, val loss 2.7567
# step 9640: train loss 2.5219, val loss 2.6793
# step 9650: train loss 2.5331, val loss 2.6800
# step 9660: train loss 2.5231, val loss 2.7121
# step 9670: train loss 2.5551, val loss 2.6433
# step 9680: train loss 2.4949, val loss 2.6098
# step 9690: train loss 2.4535, val loss 2.5120
# step 9700: train loss 2.4964, val loss 2.6541
# step 9710: train loss 2.4733, val loss 2.6237
# step 9720: train loss 2.5472, val loss 2.5268
# step 9730: train loss 2.4492, val loss 2.6722
# step 9740: train loss 2.5211, val loss 2.6855
# step 9750: train loss 2.5694, val loss 2.5465
# step 9760: train loss 2.4747, val loss 2.5483
# step 9770: train loss 2.5066, val loss 2.7416
# step 9780: train loss 2.4070, val loss 2.5696
# step 9790: train loss 2.5269, val loss 2.6393
# step 9800: train loss 2.5513, val loss 2.5156
# step 9810: train loss 2.5909, val loss 2.6329
# step 9820: train loss 2.5627, val loss 2.6710
# step 9830: train loss 2.6201, val loss 2.6661
# step 9840: train loss 2.5100, val loss 2.6302
# step 9850: train loss 2.4903, val loss 2.5648
# step 9860: train loss 2.4958, val loss 2.7779
# step 9870: train loss 2.5921, val loss 2.6513
# step 9880: train loss 2.4849, val loss 2.6691
# step 9890: train loss 2.5571, val loss 2.5435
# step 9900: train loss 2.5251, val loss 2.5523
# step 9910: train loss 2.5269, val loss 2.6097
# step 9920: train loss 2.4532, val loss 2.5759
# step 9930: train loss 2.5505, val loss 2.6076
# step 9940: train loss 2.4466, val loss 2.6351
# step 9950: train loss 2.5736, val loss 2.5699
# step 9960: train loss 2.4707, val loss 2.6531
# step 9970: train loss 2.4965, val loss 2.6502
# step 9980: train loss 2.5548, val loss 2.7433
# step 9990: train loss 2.5190, val loss 2.5501
#
# Texte généré après 10000 itérations:
#
# MUGDU
# C!
# Vù,
# Ple vofar, qun lanui;8gn ds'UBël?ât!»C'on Éâ_2?)uxcoû]d, PPanglgat,  ble,
# Rî C0Êç;
# Qïêk

# %% [markdown]
# ## Single Head Attention
#
# Nous allons maintenant implémenter le mécanisme de base de l'attention. Pour chaque couple de mots de la séquence, ce mécanisme combine Q une *query* (l'information recherchée), K une *key* (l'information obtenue) et calcule  V une *value*, un vecteur de résultat.
#
# ![single head attention](images/single_head_attention.png)
#
# ### Masquage
# Cependant, comme nous utilisons le modèle pour générer des séquences, on ne doit pas utiliser les caractères situés après le caractère courant, car ce sont justement ces caractères que l'on cherche à prédire lors de l'apprentissage : *le futur n'est pas utilisé pour prédire (le futur).*
#
# On va donc intégrer une matrice de masquage dans le processus. Cette matrice indique que pour le premier caractère de la séquence, on ne peux utiliser que ce caractère pour prédire (pas de contexte). Pour le second caractère, on peut utiliser le premier caractère et le second. Pour le troisième caractère, on peut utiliser le premier, le second et le troisième et ainsi de suite. Cette matrice est donc une matrice triangulaire inférieure. Cette matrice est normalisée par ligne (les lignes somment à 1).

# %%
T = 8

# first version of the contraints with matrix multiplication
# create a lower triangular matrix
weights0 = torch.tril(torch.ones(T,T))
# normalize each row
weights0 = weights0 / weights0.sum(1, keepdim=True) 
print (weights0)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %% [markdown]
# La couche [`softmax`](https://pytorch.org/docs/stable/generated/torch.nn.functional.softmax.html) est une autre manière de réaliser la normalisation :
#
# Question :
# > * Vérifier qu'on obtient bien la même matrice.

# %%
tril = torch.tril(torch.ones(T,T))
weights = torch.tril(torch.ones(T,T))
weights = weights.masked_fill(tril== 0, float('-inf'))
weights = nn.functional.softmax(weights, dim=-1)
print (weights)
# Out:
# tensor([[1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.3333, 0.3333, 0.3333, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2500, 0.2500, 0.2500, 0.2500, 0.0000, 0.0000, 0.0000, 0.0000],
#         [0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.0000, 0.0000, 0.0000],
#         [0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.1667, 0.0000, 0.0000],
#         [0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.1429, 0.0000],
#         [0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250, 0.1250]])

# %%
assert torch.equal(weights, weights0)

# %% [markdown]
# ### Implémentation
#
# Nous pouvons maintenant implémenter la couche d'attention :
#
# ![attention_formula](images/attention_formula.png)

# %% [markdown]
# Questions :
#
# > * Créer les couches key, query et value comme des couches linéaires de dimension `C` x `head_size`.
# > * Appliquer les couches à `x`.
# > * `weights = query x key` (transposer les deuxième et troisième dimensions de key pour pouvoir faire le produit).
# > * Appliquer le facteur de normalisation.
# > * Appliquer le masque triangulaire et la softmax à `weights`.
# > * Appliquer value à `x`.
# > * Le résultat `out` est la multiplication de `weights` par `value(x)`.

# %%
head_size = 16
B, T, C = 4, 8, 32
x = torch.randn(B, T, C)

# define the Key layer  
key = nn.Linear(C, head_size, bias=False)
# define the Query layer
query = nn.Linear(C, head_size, bias=False)
# define the Value layer
value = nn.Linear(C, head_size, bias=False)

# apply each layer to the input
k = key(x)  # (B, T, head_size)
q = query(x)  # (B, T, head_size)
v = value(x)  # (B, T, head_size)

# compute the normalize product between Q and K 
weights = q @ k.transpose(-2, -1)  # (B, T, head_size) @ (B, head_size, T) -> (B, T, T)

# apply scaling factor
weights = weights / (head_size ** 0.5)

# create tril mask
tril = torch.tril(torch.ones(T, T))

# apply the mask (lower triangular matrix)
weights = weights.masked_fill(tril == 0, float('-inf'))

# apply the softmax
weights = F.softmax(weights, dim=-1)

# compute output
out = weights @ v  # (B, T, T) @ (B, T, head_size) -> (B, T, head_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 30
#      27 weights = weights.masked_fill(tril == 0, float('-inf'))
#      29 # apply the softmax
# ---> 30 weights = F.softmax(weights, dim=-1)
#      32 # compute output
#      33 out = weights @ v  # (B, T, T) @ (B, T, head_size) -> (B, T, head_size)
#
# NameError: name 'F' is not defined

# %% [markdown]
# Questions :
#
# > * Copier votre code dans `gpt_single_head.py` : la définition des couches dans le constructeur de la classe `Head` et les calculs dans la fonction `forward`.
# > * Faire un entrainement.
# > * Quelle loss en train et val obtenez vous ? Le texte vous parait-il meilleur ?

# %% [markdown]
# ## Multi-head attention
#
# La *multi-head attention* est simplement le calcul en parallèle de plusieurs *single head attention*. Chacune des single head attention est concaténée pour créer la sortie de la multi-head attention. Dans la figure issue de l'article original, le nombre de *heads* dans le *multi-head* est `h`. Afin d'opérer des combinaisons pondérées sur la sortie de chacune des single head, une couche de calcul linéaire est ajoutée.
#
# ![multi head attention](images/multi_head_attention.png)
#
# Le code ci-dessous crée un module de multi-head attention.
# Questions :
# > * Dans le constructeur, créer une liste contenant `num_heads` module `Head` en utilisant la fonction [ModuleList](https://pytorch.org/docs/stable/generated/torch.nn.ModuleList.html) de pytorch.
# > * Dans la fonction `forward`, appliquer chaque single head à l'input et concaténer le résultat en utilisant la fonction [cat](https://pytorch.org/docs/stable/generated/torch.cat.html) de pytorch.

# %%
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        ## YOUR CODE HERE
        ## list of num_heads modules of type Head
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        ###
        
    def forward(self, x):
        ## YOUR CODE HERE
        ## apply each head in self.heads to x and concat the results 
        out = torch.cat([h(x) for h in self.heads], dim=-1)

        return out

# %% [markdown]
# Questions :
# > * Copier le fichier `gpt_single_head.py` en `gpt_multi_head.py`.
# > * Ajouter le module MultiHeadAttention dans `gpt_multi_head.py`.
# > * En tête de fichier, ajouter un paramètre  `n_head = 4`.
# > * Dans le module BigramLanguageModel, remplacer le module Head par un module MultiHeadAttention avec les paramètres `num_heads = n_head` et `head_size = n_embd // n_head` pour garder le même nombre de paramètres.
# > Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.009893 M parameters
# step 4999: train loss 2.1570, val loss 2.1802

# %% [markdown]
# ## Ajout d'une couche de calcul FeedForward
#
#
# Après les couches d'attention qui collectent l'information dans la séquence, une couche de calcul est ajoutée pour combiner toutes les informations de la séquence. Cette couche est un simple Multi-Layer-Perceptron avec une couche cachée et une non linéarité de type [RELU](https://pytorch.org/docs/stable/generated/torch.nn.ReLU.html).
# ![multi feedfoward](images/multi_ff.png)

# %%
class FeedForward(nn.Module):
    """ a simple MLP with RELU """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, n_embd),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# Questions :
# > * Ajouter le module `FeedForward` dans votre fichier `gpt_multi_head.py`.
# > * Ajouter cette couche `FeedForward` après la *multi-head attention*.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.

# %% [markdown]
# 0.010949 M parameters
# step 4999: train loss 2.1290, val loss 2.1216

# %% [markdown]
# ## Empiler les blocs
#
# Le réseau construit jusqu'à présent n'est en fait qu'un bloc du réseau final. Il est maintenant possible d'empiler les blocs de *multi-head attention* pour créer un réseau profond.
#
# ![multi feedfoward](images/multi_bloc.png)
#
#
# Le code suivant crée un bloc :

# %%
class Block(nn.Module):
    """ A single bloc of multi-head attention """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)

    def forward(self, x):
        x = self.sa(x)
        x = self.ffwd(x)
        return x

# %% [markdown]
# Questions :
# > * Ajouter le module `Block` dans `gpt_multi_head.py`.
# > * Modifier le code de `BigramLanguageModel` pour ajouter 3 `Block(n_embd, n_head=4)` avec un container [Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html) à la place de `MultiHeadAttention`et `FeedForward`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019205 M parameters
# step 4999: train loss 2.2080, val loss 2.2213

# %% [markdown]
# ## Amélioration de l'entraînement
#
# Si on veut continuer à augmenter la taille du réseau, il est nécessaire d'utiliser des couches permettant d'améliorer l'entraînement et ses capacités de généralisation (réduire le sur-apprentissage). Ces couches sont :
# - *skip connections* ou *residual connections*
# - les couches de normalisation
# - le dropout.
#
#
# ![multi feedfoward](images/multi_skip_norm.png)
#
#
# Questions :
# > * Dans le module Block, ajouter une skip connection en ajoutant l'input dans chaque connexion :
# ```
#         x = x + self.sa(self.ln1(x))
#         x = x + self.ffwd(self.ln2(x))
# ```
# > * Dans le module Block, ajouter 2 couches de [LayerNorm](https://pytorch.org/docs/stable/generated/torch.nn.LayerNorm.html) de taille `n_embd` avant la couche de `Multi-Head attention` et avant la `FeedForward`.
# > * Après la série de 3 blocs, ajouter une couche de LayerNorm de taille `n_embd`.
# > * Définir une variable `dropout = 0.2` en début de fichier et ajouter une couche de [Dropout](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) :
# >    * Après la couche RELU dans FeedForward
# >    * Après la couche de MultiHead dans `MultiHeadAttention`
# >    * Après la softmax dans la single head attention `Head`.
# > * Relancer l'entrainement et noter le nombre de paramètres et les loss obtenues.
#
# 0.019653 M parameters

# %% [markdown]
# ## Conclusion
#
# Les principaux éléments de GPT2 sont en place, il faut maintenant faire passer le modèle à l'échelle et l'entraîner sur une base de données beaucoup plus grande. Pour comparaison, les paramètres de [GPT2](https://huggingface.co/transformers/v2.11.0/model_doc/gpt2.html) sont :
#
# * `vocab_size = 50257` : GPT2 modélise des tokens (subwords) alors que nous modélisons des caractères. Pour nous, `vocab_size = 100`.
# * `n_positions = 1024` : la taille maximale du contexte. Pour nous, c'est `block_size = 8`.
# * `n_embd = 768`:  la dimension des embeddings. Pour nous c'est `n_embd = 32`.
# * `n_layer = 12`: le nombre de block. Pour nous c'est 3.
# * `n_head = 12`: le nombre de multi-head attention. Pour nous c'est 4.
#
# Au total, GPT2 est composé de 1,500 millions de paramètres et a été entrainé sur 8M de pages web, soit 40 Gb de texte.
#
#
# ```
# 10.816613 M parameters
# step 0: train loss 4.7847, val loss 4.7701
# step 4999: train loss 0.2683, val loss 2.1161
# time: 31m47.910s
#
# Le pêcheur où l'homme en peu de Carevante
# Sa conter des chosses qu'en ses yoitn!
#
# Ils sont là-hauts parler à leurs ténèbres
# A ceux qu'on rêve aux oiseaux des cheveux,
# Et celus qu'on tourna jamais sous le front;
# Ils se disent tu mêle aux univers.
# J'ai vu Jean vu France, potte; petits contempler,
# Et petié calme au milibre et versait,
# M'éblouissant, emportant, écoute, ingorancessible,
# On meurt s'efferayait.....--Pas cont âme parle en Apparia!
# ```
